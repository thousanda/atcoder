# %% [markdown]
# # ?を整数で置き換えてできる数字Nのうち N mod 13 = 5 となるNの数
# 大きい数の掛け算は遅いことを忘れがち

# %% [markdown]
# ## debug

# %%
class Mod13DPTable:
    MOD = 10**9 + 7
    
    def __init__(self, length):
        self.mod13 = [{j:0 for j in range(13)} for i in range(length)]
        self.MOD = 10**7 + 7
        
    def __str__(self):
        return self.mod13.__str__()
    
    def set_start(self, units_digit):
        if units_digit == '?':
            for i in range(10):
                self.mod13[0][i] = 1
        else:
            self.mod13[0][int(units_digit)] = 1
            
    def get_table(self, digit):
        return self.mod13[digit]
    
    def show_table(self, digit):
        for i in self.mod13[digit]:
            print(f'{i=}: {self.mod13[digit][i]}')
    
    def update(self, num, digit, multi):  # multi = 10**digit % 13
        for k, v in self.mod13[digit-1].items():
            remain = ((num * multi) + k) % 13
            self.mod13[digit][remain] = (self.mod13[digit][remain] + v) % Mod13DPTable.MOD

# %%
MOD = 10**9 + 7

S = '??2??5'
#S = '?44'
#S = '7?4'
#S = '?6?42???8??2??06243????9??3???7258??5??7???????774????4?1??17???9?5?70???76???'
#S = '174'
# S = input()

mod13dp = Mod13DPTable(len(S))

mod13dp.set_start(S[-1])
print(f'show_table: init: {S[-1]}')
table0 = mod13dp.show_table(0)
print()

multi = 10
for i, m in enumerate(reversed(list(S[:-1]))):
    i += 1
    print(f'show_table: {m} * 10**{i}')

    if m == '?':
        for j in range(10):
            mod13dp.update(j, i, multi)
    else:
        mod13dp.update(int(m), i, multi)

    multi = multi*10 % 13
    
    mod13dp.show_table(i)
    print()

print(mod13dp.get_table(-1)[5])
# Out:
# show_table: init: 5
# i=0: 0
# i=1: 0
# i=2: 0
# i=3: 0
# i=4: 0
# i=5: 1
# i=6: 0
# i=7: 0
# i=8: 0
# i=9: 0
# i=10: 0
# i=11: 0
# i=12: 0
#
# show_table: ? * 10**1
# i=0: 1
# i=1: 0
# i=2: 1
# i=3: 1
# i=4: 1
# i=5: 1
# i=6: 1
# i=7: 1
# i=8: 0
# i=9: 1
# i=10: 1
# i=11: 0
# i=12: 1
#
# show_table: ? * 10**2
# i=0: 8
# i=1: 7
# i=2: 8
# i=3: 8
# i=4: 7
# i=5: 8
# i=6: 8
# i=7: 8
# i=8: 7
# i=9: 8
# i=10: 8
# i=11: 7
# i=12: 8
#
# show_table: 2 * 10**3
# i=0: 8
# i=1: 8
# i=2: 7
# i=3: 8
# i=4: 8
# i=5: 8
# i=6: 7
# i=7: 8
# i=8: 8
# i=9: 7
# i=10: 8
# i=11: 8
# i=12: 7
#
# show_table: ? * 10**4
# i=0: 78
# i=1: 76
# i=2: 76
# i=3: 79
# i=4: 76
# i=5: 76
# i=6: 79
# i=7: 76
# i=8: 76
# i=9: 78
# i=10: 77
# i=11: 76
# i=12: 77
#
# show_table: ? * 10**5
# i=0: 771
# i=1: 768
# i=2: 768
# i=3: 772
# i=4: 768
# i=5: 768
# i=6: 771
# i=7: 769
# i=8: 768
# i=9: 770
# i=10: 770
# i=11: 768
# i=12: 769
#
# 768

# %% [markdown]
# ## submit

# %%
class Mod13DPTable:
    MOD = 10**9 + 7
    def __init__(self, length):
        self.mod13 = [{j:0 for j in range(13)} for i in range(length)]
        self.MOD = 10**7 + 7
    def set_start(self, units_digit):
        if units_digit == '?':
            for i in range(10):
                self.mod13[0][i] = 1
        else:
            self.mod13[0][int(units_digit)] = 1
    def get_table(self, digit):
        return self.mod13[digit]
    def update(self, num, digit, multi):  # multi = 10**digit % 13
        for k, v in self.mod13[digit-1].items():
            remain = ((num * multi) + k) % 13
            self.mod13[digit][remain] = (self.mod13[digit][remain] + v) % Mod13DPTable.MOD
            
def main():
    MOD = 10**9 + 7
    S = input()
    mod13dp = Mod13DPTable(len(S))
    mod13dp.set_start(S[-1])
    multi = 10
    for i, m in enumerate(reversed(list(S[:-1]))):
        i += 1
        if m == '?':
            for j in range(10):
                mod13dp.update(j, i, multi)
        else:
            mod13dp.update(int(m), i, multi)
        multi = multi*10 % 13
    print(mod13dp.get_table(-1)[5])
main()
# Out:
#  ?6?42???8??2??06243????9??3???7258??5??7???????774????4?1??17???9?5?70???76???
# 153716888
